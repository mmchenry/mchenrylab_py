# %% [markdown]
# # Playing with videoTools 2

# %% [markdown]
# ## Reading a video frame

# %%
import videoTools as vt
from matplotlib import pyplot as plt

# Define path (modify to your system)
vid_path = "/home/mmchenry/Videos/sample.MOV"

# Read first video frame
im = vt.getFrame(vid_path,1)

# Display frame
plt.imshow(im)
plt.show()

# Test text
